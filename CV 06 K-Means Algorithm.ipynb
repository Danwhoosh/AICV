# %% [markdown]
# ## Implement K-Means Algorithm

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/student/.conda/envs/nm21ai024/lib/python3.9/site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/student/.conda/envs/nm21ai024/lib/python3.9/site-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/student/.conda/envs/nm21ai024/lib/python3.9/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/student/.conda/envs/nm21ai024/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/student/.conda/envs/nm21ai024/lib/python3.9/site-packages (from scikit-learn) (3.2.0)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#Generate some sample data for clustering
np.random.seed(0)

# %%
x = np.random.rand(100,2)
k = 3#No of clusters

# %%
#Initialize the k means model
kmeans = KMeans(n_clusters = k)

# %%
#Fit the model
kmeans.fit(x)
# Out:
# /home/student/.conda/envs/nm21ai024/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
#Get the clusters center and labels
cluster_centers = kmeans.cluster_centers_
labels = kmeans.labels_
#Plot the data points and cluster centers
plt.scatter(x[:, 0], x[:, 1], c = labels)
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker = 'x', s = 200, color = 'red')
plt.title(f'K-Means Clustering(k = {k})')
plt.show()
